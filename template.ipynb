# %% [markdown]
# Installs everything that is needed

# %%
! pip install numpy==1.26.4 pandas==2.2.2
! pip install spacy
! python -m spacy download ro_core_news_lg
! pip install matplotlib
# Out:
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting pandas==2.2.2
#   Using cached pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/robert/IT/Facultate/Licenta/.venv/lib/python3.10/site-packages (from pandas==2.2.2) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas==2.2.2)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.2.2)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/robert/IT/Facultate/Licenta/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Using cached pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]2m3/4 [pandas]
# Successfully installed numpy-1.26.4 pandas-2.2.2 pytz-2025.2 tzdata-2025.2
# Collecting spacy
#   Using cached spacy-3.8.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Using cached murmurhash-1.0.13-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Using cached cymem-2.0.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.5 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Using cached preshed-3.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.4 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Using cached thinc-8.3.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Using cached srsly-2.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.16.1-py3-none-any.whl.metadata (15 kB)
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: numpy>=1.19.0 in /home/robert/IT/Facultate/Licenta/.venv/lib/python3.10/site-packages (from spacy) (1.26.4)
# Collecting requests<3.0.0,>=2.13.0 (from spacy)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting jinja2 (from spacy)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: setuptools in /home/robert/IT/Facultate/Licenta/.venv/lib/python3.10/site-packages (from spacy) (59.6.0)
# Requirement already satisfied: packaging>=20.0 in /home/robert/IT/Facultate/Licenta/.venv/lib/python3.10/site-packages (from spacy) (25.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Using cached langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Using cached language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached pydantic_core-2.33.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/robert/IT/Facultate/Licenta/.venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.1)
# Collecting typing-inspection>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading charset_normalizer-3.4.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Using cached blis-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting numpy>=1.19.0 (from spacy)
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting click>=8.0.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Using cached cloudpathlib-0.21.1-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading smart_open-7.3.0.post1-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy)
#   Downloading wrapt-1.17.3-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.4 kB)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.3.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/robert/IT/Facultate/Licenta/.venv/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy)
#   Using cached MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Using cached spacy-3.8.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.5 MB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached cymem-2.0.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (204 kB)
# Using cached langcodes-3.5.0-py3-none-any.whl (182 kB)
# Using cached murmurhash-1.0.13-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
# Using cached preshed-3.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (795 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (152 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Using cached srsly-2.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Using cached thinc-8.3.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
# Using cached blis-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typer-0.16.1-py3-none-any.whl (46 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-0.4.1-py3-none-any.whl (50 kB)
# Using cached cloudpathlib-0.21.1-py3-none-any.whl (52 kB)
# Downloading smart_open-7.3.0.post1-py3-none-any.whl (61 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
# Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Using cached language_data-1.3.0-py3-none-any.whl (5.4 MB)
# Downloading marisa_trie-1.3.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 950.4 kB/s  0:00:01 eta 0:00:01
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Downloading wrapt-1.17.3-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (81 kB)
# Installing collected packages: cymem, wrapt, wasabi, urllib3, typing-inspection, tqdm, spacy-loggers, spacy-legacy, shellingham, pydantic-core, numpy, murmurhash, mdurl, MarkupSafe, marisa-trie, idna, cloudpathlib, click, charset_normalizer, certifi, catalogue, annotated-types, srsly, smart-open, requests, pydantic, preshed, markdown-it-py, language-data, jinja2, blis, rich, langcodes, confection, typer, thinc, weasel, spacy
#   Attempting uninstall: numpy0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/38 [pydantic-core]
#     Found existing installation: numpy 1.26.4━━━━━━━━━━━━━━━━━  9/38 [pydantic-core]
#     Uninstalling numpy-1.26.4:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/38 [pydantic-core]
#       Successfully uninstalled numpy-1.26.4━━━━━━━━━━━━━━━━━━━  9/38 [pydantic-core]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38/38 [spacy]m37/38 [spacy]ge-data]izer]
# Successfully installed MarkupSafe-3.0.2 annotated-types-0.7.0 blis-1.3.0 catalogue-2.0.10 certifi-2025.8.3 charset_normalizer-3.4.3 click-8.2.1 cloudpathlib-0.21.1 confection-0.1.5 cymem-2.0.11 idna-3.10 jinja2-3.1.6 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.3.0 markdown-it-py-4.0.0 mdurl-0.1.2 murmurhash-1.0.13 numpy-2.2.6 preshed-3.0.10 pydantic-2.11.7 pydantic-core-2.33.2 requests-2.32.5 rich-14.1.0 shellingham-1.5.4 smart-open-7.3.0.post1 spacy-3.8.7 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.1 thinc-8.3.6 tqdm-4.67.1 typer-0.16.1 typing-inspection-0.4.1 urllib3-2.5.0 wasabi-1.1.3 weasel-0.4.1 wrapt-1.17.3
# Collecting ro-core-news-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ro_core_news_lg-3.8.0/ro_core_news_lg-3.8.0-py3-none-any.whl (568.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.5/568.5 MB 3.1 MB/s  0:02:560:00:0100:05
# Installing collected packages: ro-core-news-lg
# Successfully installed ro-core-news-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ro_core_news_lg')
# Collecting matplotlib
#   Downloading matplotlib-3.10.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.59.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (108 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /home/robert/IT/Facultate/Licenta/.venv/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/robert/IT/Facultate/Licenta/.venv/lib/python3.10/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/robert/IT/Facultate/Licenta/.venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/robert/IT/Facultate/Licenta/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 1.7 MB/s  0:00:05 eta 0:00:01
# Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 2.5 MB/s  0:00:01 eta 0:00:01
# Downloading kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 3.7 MB/s  0:00:00 eta 0:00:01
# Downloading pillow-11.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 2.0 MB/s  0:00:03 eta 0:00:01
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.59.1 kiwisolver-1.4.9 matplotlib-3.10.5 pillow-11.3.0 pyparsing-3.2.3

# %% [markdown]
# Initialise libraries for Analysis

# %%
import os
import pandas as pd
import spacy
import numpy as np
from collections import Counter, defaultdict
from pathlib import Path
import json, csv, re, sys

# %% [markdown]
# Load SpaCy Ro Model

# %%
spacy_model = spacy.load('ro_core_news_lg')

# %% [markdown]
# ## Load files
#
# We will load all files. They are stored in subfolders, creating smaller and smaller categories.

# %%
ROOT = Path("data")

for fp in ROOT.rglob("*.json"): 
    try: 
        data = json.loads(fp.read_text(encoding="utf-8"))
    except Exception as e: 
        print(f"[err] {fp}: {e}")
        continue

    # get folder path for categories

    rel_path = fp.relative_to(ROOT)
    category_path = rel_path.parent.as_posix()
    filename = fp.name

    print (f"[*] {filename} -> {category_path}")
# Out:
# [*] Anglia_Mea_0482.json -> int/UK
# [*] Anglia_Mea_0398.json -> int/UK
# [*] Anglia_Mea_0330.json -> int/UK
# [*] Anglia_Mea_0238.json -> int/UK
# [*] Anglia_Mea_0195.json -> int/UK
# [*] Anglia_Mea_0451.json -> int/UK
# [*] Anglia_Mea_0417.json -> int/UK
# [*] Anglia_Mea_0374.json -> int/UK
# [*] Anglia_Mea_0324.json -> int/UK
# [*] Anglia_Mea_0060.json -> int/UK
# [*] Anglia_Mea_0315.json -> int/UK
# [*] Anglia_Mea_0341.json -> int/UK
# [*] Anglia_Mea_0333.json -> int/UK
# [*] Anglia_Mea_0014.json -> int/UK
# [*] Anglia_Mea_0221.json -> int/UK
# [*] Anglia_Mea_0062.json -> int/UK
# [*] Anglia_Mea_0007.json -> int/UK
# [*] Anglia_Mea_0319.json -> int/UK
# [*] Anglia_Mea_0289.json -> int/UK
# [*] Anglia_Mea_0325.json -> int/UK
# [*] Anglia_Mea_0176.json -> int/UK
# [*] Anglia_Mea_0465.json -> int/UK
# [*] Anglia_Mea_0124.json -> int/UK
# [*] Anglia_Mea_0005.json -> int/UK
# [*] Anglia_Mea_0050.json -> int/UK
# [*] Anglia_Mea_0271.json -> int/UK
# [*] Anglia_Mea_0354.json -> int/UK
# [*] Anglia_Mea_0058.json -> int/UK
# [*] Anglia_Mea_0488.json -> int/UK
# [*] Anglia_Mea_0169.json -> int/UK
# [*] Anglia_Mea_0239.json -> int/UK
# [*] Anglia_Mea_0073.json -> int/UK
# [*] Anglia_Mea_0492.json -> int/UK
# [*] Anglia_Mea_0314.json -> int/UK
# [*] Anglia_Mea_0284.json -> int/UK
# [*] Anglia_Mea_0121.json -> int/UK
# [*] Anglia_Mea_0331.json -> int/UK
# [*] Anglia_Mea_0348.json -> int/UK
# [*] Anglia_Mea_0469.json -> int/UK
# [*] Anglia_Mea_0204.json -> int/UK
# [*] Anglia_Mea_0025.json -> int/UK
# [*] Anglia_Mea_0470.json -> int/UK
# [*] Anglia_Mea_0337.json -> int/UK
# [*] Anglia_Mea_0183.json -> int/UK
# [*] Anglia_Mea_0459.json -> int/UK
# [*] Anglia_Mea_0215.json -> int/UK
# [*] Anglia_Mea_0141.json -> int/UK
# [*] Anglia_Mea_0038.json -> int/UK
# [*] Anglia_Mea_0279.json -> int/UK
# [*] Anglia_Mea_0246.json -> int/UK
# [*] Anglia_Mea_0111.json -> int/UK
# [*] Anglia_Mea_0228.json -> int/UK
# [*] Anglia_Mea_0109.json -> int/UK
# [*] Anglia_Mea_0031.json -> int/UK
# [*] Anglia_Mea_0420.json -> int/UK
# [*] Anglia_Mea_0040.json -> int/UK
# [*] Anglia_Mea_0064.json -> int/UK
# [*] Anglia_Mea_0457.json -> int/UK
# [*] Anglia_Mea_0371.json -> int/UK
# [*] Anglia_Mea_0266.json -> int/UK
# [*] Anglia_Mea_0413.json -> int/UK
# [*] Anglia_Mea_0217.json -> int/UK
# [*] Anglia_Mea_0347.json -> int/UK
# [*] Anglia_Mea_0497.json -> int/UK
# [*] Anglia_Mea_0381.json -> int/UK
# [*] Anglia_Mea_0053.json -> int/UK
# [*] Anglia_Mea_0027.json -> int/UK
# [*] Anglia_Mea_0363.json -> int/UK
# [*] Anglia_Mea_0448.json -> int/UK
# [*] Anglia_Mea_0227.json -> int/UK
# [*] Anglia_Mea_0301.json -> int/UK
# [*] Anglia_Mea_0138.json -> int/UK
# [*] Anglia_Mea_0346.json -> int/UK
# [*] Anglia_Mea_0088.json -> int/UK
# [*] Anglia_Mea_0099.json -> int/UK
# [*] Anglia_Mea_0033.json -> int/UK
# [*] Anglia_Mea_0049.json -> int/UK
# [*] Anglia_Mea_0211.json -> int/UK
# [*] Anglia_Mea_0012.json -> int/UK
# [*] Anglia_Mea_0225.json -> int/UK
# [*] Anglia_Mea_0184.json -> int/UK
# [*] Anglia_Mea_0480.json -> int/UK
# [*] Anglia_Mea_0154.json -> int/UK
# [*] Anglia_Mea_0355.json -> int/UK
# [*] Anglia_Mea_0393.json -> int/UK
# [*] Anglia_Mea_0131.json -> int/UK
# [*] Anglia_Mea_0479.json -> int/UK
# [*] Anglia_Mea_0068.json -> int/UK
# [*] Anglia_Mea_0158.json -> int/UK
# [*] Anglia_Mea_0129.json -> int/UK
# [*] Anglia_Mea_0133.json -> int/UK
# [*] Anglia_Mea_0232.json -> int/UK
# [*] Anglia_Mea_0093.json -> int/UK
# [*] Anglia_Mea_0202.json -> int/UK
# [*] Anglia_Mea_0052.json -> int/UK
# [*] Anglia_Mea_0234.json -> int/UK
# [*] Anglia_Mea_0407.json -> int/UK
# [*] Anglia_Mea_0023.json -> int/UK
# [*] Anglia_Mea_0380.json -> int/UK
# [*] Anglia_Mea_0373.json -> int/UK
# [*] Anglia_Mea_0306.json -> int/UK
# [*] Anglia_Mea_0091.json -> int/UK
# [*] Anglia_Mea_0089.json -> int/UK
# [*] Anglia_Mea_0095.json -> int/UK
# [*] Anglia_Mea_0447.json -> int/UK
# [*] Anglia_Mea_0342.json -> int/UK
# [*] Anglia_Mea_0474.json -> int/UK
# [*] Anglia_Mea_0029.json -> int/UK
# [*] Anglia_Mea_0273.json -> int/UK
# [*] Anglia_Mea_0148.json -> int/UK
# [*] Anglia_Mea_0218.json -> int/UK
# [*] Anglia_Mea_0039.json -> int/UK
# [*] Anglia_Mea_0268.json -> int/UK
# [*] Anglia_Mea_0345.json -> int/UK
# [*] Anglia_Mea_0418.json -> int/UK
# [*] Anglia_Mea_0353.json -> int/UK
# [*] Anglia_Mea_0249.json -> int/UK
# [*] Anglia_Mea_0151.json -> int/UK
# [*] Anglia_Mea_0194.json -> int/UK
# [*] Anglia_Mea_0147.json -> int/UK
# [*] Anglia_Mea_0259.json -> int/UK
# [*] Anglia_Mea_0132.json -> int/UK
# [*] Anglia_Mea_0156.json -> int/UK
# [*] Anglia_Mea_0340.json -> int/UK
# [*] Anglia_Mea_0400.json -> int/UK
# [*] Anglia_Mea_0414.json -> int/UK
# [*] Anglia_Mea_0445.json -> int/UK
# [*] Anglia_Mea_0369.json -> int/UK
# [*] Anglia_Mea_0499.json -> int/UK
# [*] Anglia_Mea_0206.json -> int/UK
# [*] Anglia_Mea_0377.json -> int/UK
# [*] Anglia_Mea_0004.json -> int/UK
# [*] Anglia_Mea_0143.json -> int/UK
# [*] Anglia_Mea_0403.json -> int/UK
# [*] Anglia_Mea_0486.json -> int/UK
# [*] Anglia_Mea_0069.json -> int/UK
# [*] Anglia_Mea_0356.json -> int/UK
# [*] Anglia_Mea_0255.json -> int/UK
# [*] Anglia_Mea_0484.json -> int/UK
# [*] Anglia_Mea_0006.json -> int/UK
# [*] Anglia_Mea_0389.json -> int/UK
# [*] Anglia_Mea_0114.json -> int/UK
# [*] Anglia_Mea_0394.json -> int/UK
# [*] Anglia_Mea_0496.json -> int/UK
# [*] Anglia_Mea_0245.json -> int/UK
# [*] Anglia_Mea_0181.json -> int/UK
# [*] Anglia_Mea_0157.json -> int/UK
# [*] Anglia_Mea_0161.json -> int/UK
# [*] Anglia_Mea_0466.json -> int/UK
# [*] Anglia_Mea_0295.json -> int/UK
# [*] Anglia_Mea_0329.json -> int/UK
# [*] Anglia_Mea_0094.json -> int/UK
# [*] Anglia_Mea_0065.json -> int/UK
# [*] Anglia_Mea_0205.json -> int/UK
# [*] Anglia_Mea_0424.json -> int/UK
# [*] Anglia_Mea_0257.json -> int/UK
# [*] Anglia_Mea_0296.json -> int/UK
# [*] Anglia_Mea_0242.json -> int/UK
# [*] Anglia_Mea_0237.json -> int/UK
# [*] Anglia_Mea_0489.json -> int/UK
# [*] Anglia_Mea_0455.json -> int/UK
# [*] Anglia_Mea_0122.json -> int/UK
# [*] Anglia_Mea_0002.json -> int/UK
# [*] Anglia_Mea_0243.json -> int/UK
# [*] Anglia_Mea_0378.json -> int/UK
# [*] Anglia_Mea_0461.json -> int/UK
# [*] Anglia_Mea_0494.json -> int/UK
# [*] Anglia_Mea_0186.json -> int/UK
# [*] Anglia_Mea_0392.json -> int/UK
# [*] Anglia_Mea_0309.json -> int/UK
# [*] Anglia_Mea_0028.json -> int/UK
# [*] Anglia_Mea_0096.json -> int/UK
# [*] Anglia_Mea_0152.json -> int/UK
# [*] Anglia_Mea_0229.json -> int/UK
# [*] Anglia_Mea_0167.json -> int/UK
# [*] Anglia_Mea_0071.json -> int/UK
# [*] Anglia_Mea_0262.json -> int/UK
# [*] Anglia_Mea_0168.json -> int/UK
# [*] Anglia_Mea_0057.json -> int/UK
# [*] Anglia_Mea_0308.json -> int/UK
# [*] Anglia_Mea_0000.json -> int/UK
# [*] Anglia_Mea_0100.json -> int/UK
# [*] Anglia_Mea_0351.json -> int/UK
# [*] Anglia_Mea_0473.json -> int/UK
# [*] Anglia_Mea_0001.json -> int/UK
# [*] Anglia_Mea_0032.json -> int/UK
# [*] Anglia_Mea_0285.json -> int/UK
# [*] Anglia_Mea_0037.json -> int/UK
# [*] Anglia_Mea_0383.json -> int/UK
# [*] Anglia_Mea_0401.json -> int/UK
# [*] Anglia_Mea_0222.json -> int/UK
# [*] Anglia_Mea_0021.json -> int/UK
# [*] Anglia_Mea_0180.json -> int/UK
# [*] Anglia_Mea_0189.json -> int/UK
# [*] Anglia_Mea_0426.json -> int/UK
# [*] Anglia_Mea_0059.json -> int/UK
# [*] Anglia_Mea_0336.json -> int/UK
# [*] Anglia_Mea_0086.json -> int/UK
# [*] Anglia_Mea_0436.json -> int/UK
# [*] Anglia_Mea_0048.json -> int/UK
# [*] Anglia_Mea_0051.json -> int/UK
# [*] Anglia_Mea_0490.json -> int/UK
# [*] Anglia_Mea_0072.json -> int/UK
# [*] Anglia_Mea_0090.json -> int/UK
# [*] Anglia_Mea_0458.json -> int/UK
# [*] Anglia_Mea_0280.json -> int/UK
# [*] Anglia_Mea_0260.json -> int/UK
# [*] Anglia_Mea_0163.json -> int/UK
# [*] Anglia_Mea_0335.json -> int/UK
# [*] Anglia_Mea_0044.json -> int/UK
# [*] Anglia_Mea_0444.json -> int/UK
# [*] Anglia_Mea_0075.json -> int/UK
# [*] Anglia_Mea_0116.json -> int/UK
# [*] Anglia_Mea_0361.json -> int/UK
# [*] Anglia_Mea_0454.json -> int/UK
# [*] Anglia_Mea_0251.json -> int/UK
# [*] Anglia_Mea_0019.json -> int/UK
# [*] Anglia_Mea_0422.json -> int/UK
# [*] Anglia_Mea_0382.json -> int/UK
# [*] Anglia_Mea_0428.json -> int/UK
# [*] Anglia_Mea_0276.json -> int/UK
# [*] Anglia_Mea_0193.json -> int/UK
# [*] Anglia_Mea_0066.json -> int/UK
# [*] Anglia_Mea_0471.json -> int/UK
# [*] Anglia_Mea_0269.json -> int/UK
# [*] Anglia_Mea_0429.json -> int/UK
# [*] Anglia_Mea_0108.json -> int/UK
# [*] Anglia_Mea_0079.json -> int/UK
# [*] Anglia_Mea_0076.json -> int/UK
# [*] Anglia_Mea_0419.json -> int/UK
# [*] Anglia_Mea_0223.json -> int/UK
# [*] Anglia_Mea_0041.json -> int/UK
# [*] Anglia_Mea_0272.json -> int/UK
# [*] Anglia_Mea_0253.json -> int/UK
# [*] Anglia_Mea_0300.json -> int/UK
# [*] Anglia_Mea_0235.json -> int/UK
# [*] Anglia_Mea_0128.json -> int/UK
# [*] Anglia_Mea_0226.json -> int/UK
# [*] Anglia_Mea_0146.json -> int/UK
# [*] Anglia_Mea_0388.json -> int/UK
# [*] Anglia_Mea_0318.json -> int/UK
# [*] Anglia_Mea_0030.json -> int/UK
# [*] Anglia_Mea_0016.json -> int/UK
# [*] Anglia_Mea_0063.json -> int/UK
# [*] Anglia_Mea_0212.json -> int/UK
# [*] Anglia_Mea_0467.json -> int/UK
# [*] Anglia_Mea_0123.json -> int/UK
# [*] Anglia_Mea_0303.json -> int/UK
# [*] Anglia_Mea_0278.json -> int/UK
# [*] Anglia_Mea_0487.json -> int/UK
# [*] Anglia_Mea_0080.json -> int/UK
# [*] Anglia_Mea_0416.json -> int/UK
# [*] Anglia_Mea_0137.json -> int/UK
# [*] Anglia_Mea_0134.json -> int/UK
# [*] Anglia_Mea_0020.json -> int/UK
# [*] Anglia_Mea_0440.json -> int/UK
# [*] Anglia_Mea_0026.json -> int/UK
# [*] Anglia_Mea_0339.json -> int/UK
# [*] Anglia_Mea_0140.json -> int/UK
# [*] Anglia_Mea_0159.json -> int/UK
# [*] Anglia_Mea_0074.json -> int/UK
# [*] Anglia_Mea_0105.json -> int/UK
# [*] Anglia_Mea_0464.json -> int/UK
# [*] Anglia_Mea_0261.json -> int/UK
# [*] Anglia_Mea_0409.json -> int/UK
# [*] Anglia_Mea_0113.json -> int/UK
# [*] Anglia_Mea_0468.json -> int/UK
# [*] Anglia_Mea_0450.json -> int/UK
# [*] Anglia_Mea_0423.json -> int/UK
# [*] Anglia_Mea_0476.json -> int/UK
# [*] Anglia_Mea_0456.json -> int/UK
# [*] Anglia_Mea_0171.json -> int/UK
# [*] Anglia_Mea_0216.json -> int/UK
# [*] Anglia_Mea_0438.json -> int/UK
# [*] Anglia_Mea_0446.json -> int/UK
# [*] Anglia_Mea_0061.json -> int/UK
# [*] Anglia_Mea_0214.json -> int/UK
# [*] Anglia_Mea_0231.json -> int/UK
# [*] Anglia_Mea_0349.json -> int/UK
# [*] Anglia_Mea_0078.json -> int/UK
# [*] Anglia_Mea_0434.json -> int/UK
# [*] Anglia_Mea_0326.json -> int/UK
# [*] Anglia_Mea_0364.json -> int/UK
# [*] Anglia_Mea_0097.json -> int/UK
# [*] Anglia_Mea_0263.json -> int/UK
# [*] Anglia_Mea_0187.json -> int/UK
# [*] Anglia_Mea_0230.json -> int/UK
# [*] Anglia_Mea_0201.json -> int/UK
# [*] Anglia_Mea_0054.json -> int/UK
# [*] Anglia_Mea_0435.json -> int/UK
# [*] Anglia_Mea_0343.json -> int/UK
# [*] Anglia_Mea_0323.json -> int/UK
# [*] Anglia_Mea_0344.json -> int/UK
# [*] Anglia_Mea_0101.json -> int/UK
# [*] Anglia_Mea_0386.json -> int/UK
# [*] Anglia_Mea_0311.json -> int/UK
# [*] Anglia_Mea_0120.json -> int/UK
# [*] Anglia_Mea_0142.json -> int/UK
# [*] Anglia_Mea_0350.json -> int/UK
# [*] Anglia_Mea_0365.json -> int/UK
# [*] Anglia_Mea_0009.json -> int/UK
# [*] Anglia_Mea_0283.json -> int/UK
# [*] Anglia_Mea_0191.json -> int/UK
# [*] Anglia_Mea_0166.json -> int/UK
# [*] Anglia_Mea_0188.json -> int/UK
# [*] Anglia_Mea_0190.json -> int/UK
# [*] Anglia_Mea_0139.json -> int/UK
# [*] Anglia_Mea_0046.json -> int/UK
# [*] Anglia_Mea_0265.json -> int/UK
# [*] Anglia_Mea_0165.json -> int/UK
# [*] Anglia_Mea_0178.json -> int/UK
# [*] Anglia_Mea_0427.json -> int/UK
# [*] Anglia_Mea_0431.json -> int/UK
# [*] Anglia_Mea_0379.json -> int/UK
# [*] Anglia_Mea_0462.json -> int/UK
# [*] Anglia_Mea_0472.json -> int/UK
# [*] Anglia_Mea_0449.json -> int/UK
# [*] Anglia_Mea_0313.json -> int/UK
# [*] Anglia_Mea_0185.json -> int/UK
# [*] Anglia_Mea_0442.json -> int/UK
# [*] Anglia_Mea_0082.json -> int/UK
# [*] Anglia_Mea_0224.json -> int/UK
# [*] Anglia_Mea_0092.json -> int/UK
# [*] Anglia_Mea_0179.json -> int/UK
# [*] Anglia_Mea_0304.json -> int/UK
# [*] Anglia_Mea_0200.json -> int/UK
# [*] Anglia_Mea_0498.json -> int/UK
# [*] Anglia_Mea_0254.json -> int/UK
# [*] Anglia_Mea_0305.json -> int/UK
# [*] Anglia_Mea_0210.json -> int/UK
# [*] Anglia_Mea_0408.json -> int/UK
# [*] Anglia_Mea_0118.json -> int/UK
# [*] Anglia_Mea_0241.json -> int/UK
# [*] Anglia_Mea_0404.json -> int/UK
# [*] Anglia_Mea_0475.json -> int/UK
# [*] Anglia_Mea_0463.json -> int/UK
# [*] Anglia_Mea_0267.json -> int/UK
# [*] Anglia_Mea_0368.json -> int/UK
# [*] Anglia_Mea_0287.json -> int/UK
# [*] Anglia_Mea_0127.json -> int/UK
# [*] Anglia_Mea_0258.json -> int/UK
# [*] Anglia_Mea_0433.json -> int/UK
# [*] Anglia_Mea_0177.json -> int/UK
# [*] Anglia_Mea_0430.json -> int/UK
# [*] Anglia_Mea_0045.json -> int/UK
# [*] Anglia_Mea_0352.json -> int/UK
# [*] Anglia_Mea_0034.json -> int/UK
# [*] Anglia_Mea_0107.json -> int/UK
# [*] Anglia_Mea_0332.json -> int/UK
# [*] Anglia_Mea_0117.json -> int/UK
# [*] Anglia_Mea_0406.json -> int/UK
# [*] Anglia_Mea_0264.json -> int/UK
# [*] Anglia_Mea_0102.json -> int/UK
# [*] Anglia_Mea_0149.json -> int/UK
# [*] Anglia_Mea_0491.json -> int/UK
# [*] Anglia_Mea_0397.json -> int/UK
# [*] Anglia_Mea_0391.json -> int/UK
# [*] Anglia_Mea_0310.json -> int/UK
# [*] Anglia_Mea_0411.json -> int/UK
# [*] Anglia_Mea_0395.json -> int/UK
# [*] Anglia_Mea_0358.json -> int/UK
# [*] Anglia_Mea_0298.json -> int/UK
# [*] Anglia_Mea_0493.json -> int/UK
# [*] Anglia_Mea_0209.json -> int/UK
# [*] Anglia_Mea_0208.json -> int/UK
# [*] Anglia_Mea_0011.json -> int/UK
# [*] Anglia_Mea_0317.json -> int/UK
# [*] Anglia_Mea_0282.json -> int/UK
# [*] Anglia_Mea_0415.json -> int/UK
# [*] Anglia_Mea_0070.json -> int/UK
# [*] Anglia_Mea_0233.json -> int/UK
# [*] Anglia_Mea_0056.json -> int/UK
# [*] Anglia_Mea_0248.json -> int/UK
# [*] Anglia_Mea_0199.json -> int/UK
# [*] Anglia_Mea_0477.json -> int/UK
# [*] Anglia_Mea_0256.json -> int/UK
# [*] Anglia_Mea_0270.json -> int/UK
# [*] Anglia_Mea_0240.json -> int/UK
# [*] Anglia_Mea_0196.json -> int/UK
# [*] Anglia_Mea_0294.json -> int/UK
# [*] Anglia_Mea_0293.json -> int/UK
# [*] Anglia_Mea_0277.json -> int/UK
# [*] Anglia_Mea_0412.json -> int/UK
# [*] Anglia_Mea_0495.json -> int/UK
# [*] Anglia_Mea_0275.json -> int/UK
# [*] Anglia_Mea_0036.json -> int/UK
# [*] Anglia_Mea_0478.json -> int/UK
# [*] Anglia_Mea_0402.json -> int/UK
# [*] Anglia_Mea_0385.json -> int/UK
# [*] Anglia_Mea_0197.json -> int/UK
# [*] Anglia_Mea_0067.json -> int/UK
# [*] Anglia_Mea_0372.json -> int/UK
# [*] Anglia_Mea_0410.json -> int/UK
# [*] Anglia_Mea_0483.json -> int/UK
# [*] Anglia_Mea_0119.json -> int/UK
# [*] Anglia_Mea_0297.json -> int/UK
# [*] Anglia_Mea_0437.json -> int/UK
# [*] Anglia_Mea_0219.json -> int/UK
# [*] Anglia_Mea_0145.json -> int/UK
# [*] Anglia_Mea_0286.json -> int/UK
# [*] Anglia_Mea_0328.json -> int/UK
# [*] Anglia_Mea_0396.json -> int/UK
# [*] Anglia_Mea_0405.json -> int/UK
# [*] Anglia_Mea_0441.json -> int/UK
# [*] Anglia_Mea_0175.json -> int/UK
# [*] Anglia_Mea_0390.json -> int/UK
# [*] Anglia_Mea_0022.json -> int/UK
# [*] Anglia_Mea_0320.json -> int/UK
# [*] Anglia_Mea_0292.json -> int/UK
# [*] Anglia_Mea_0291.json -> int/UK
# [*] Anglia_Mea_0083.json -> int/UK
# [*] Anglia_Mea_0112.json -> int/UK
# [*] Anglia_Mea_0322.json -> int/UK
# [*] Anglia_Mea_0220.json -> int/UK
# [*] Anglia_Mea_0299.json -> int/UK
# [*] Anglia_Mea_0387.json -> int/UK
# [*] Anglia_Mea_0130.json -> int/UK
# [*] Anglia_Mea_0017.json -> int/UK
# [*] Anglia_Mea_0008.json -> int/UK
# [*] Anglia_Mea_0150.json -> int/UK
# [*] Anglia_Mea_0288.json -> int/UK
# [*] Anglia_Mea_0081.json -> int/UK
# [*] Anglia_Mea_0106.json -> int/UK
# [*] Anglia_Mea_0307.json -> int/UK
# [*] Anglia_Mea_0453.json -> int/UK
# [*] Anglia_Mea_0174.json -> int/UK
# [*] Anglia_Mea_0485.json -> int/UK
# [*] Anglia_Mea_0399.json -> int/UK
# [*] Anglia_Mea_0098.json -> int/UK
# [*] Anglia_Mea_0334.json -> int/UK
# [*] Anglia_Mea_0207.json -> int/UK
# [*] Anglia_Mea_0236.json -> int/UK
# [*] Anglia_Mea_0366.json -> int/UK
# [*] Anglia_Mea_0047.json -> int/UK
# [*] Anglia_Mea_0135.json -> int/UK
# [*] Anglia_Mea_0010.json -> int/UK
# [*] Anglia_Mea_0136.json -> int/UK
# [*] Anglia_Mea_0155.json -> int/UK
# [*] Anglia_Mea_0360.json -> int/UK
# [*] Anglia_Mea_0481.json -> int/UK
# [*] Anglia_Mea_0252.json -> int/UK
# [*] Anglia_Mea_0104.json -> int/UK
# [*] Anglia_Mea_0213.json -> int/UK
# [*] Anglia_Mea_0160.json -> int/UK
# [*] Anglia_Mea_0018.json -> int/UK
# [*] Anglia_Mea_0247.json -> int/UK
# [*] Anglia_Mea_0370.json -> int/UK
# [*] Anglia_Mea_0182.json -> int/UK
# [*] Anglia_Mea_0144.json -> int/UK
# [*] Anglia_Mea_0192.json -> int/UK
# [*] Anglia_Mea_0077.json -> int/UK
# [*] Anglia_Mea_0250.json -> int/UK
# [*] Anglia_Mea_0421.json -> int/UK
# [*] Anglia_Mea_0357.json -> int/UK
# [*] Anglia_Mea_0087.json -> int/UK
# [*] Anglia_Mea_0126.json -> int/UK
# [*] Anglia_Mea_0384.json -> int/UK
# [*] Anglia_Mea_0338.json -> int/UK
# [*] Anglia_Mea_0203.json -> int/UK
# [*] Anglia_Mea_0110.json -> int/UK
# [*] Anglia_Mea_0460.json -> int/UK
# [*] Anglia_Mea_0443.json -> int/UK
# [*] Anglia_Mea_0274.json -> int/UK
# [*] Anglia_Mea_0316.json -> int/UK
# [*] Anglia_Mea_0055.json -> int/UK
# [*] Anglia_Mea_0359.json -> int/UK
# [*] Anglia_Mea_0172.json -> int/UK
# [*] Anglia_Mea_0162.json -> int/UK
# [*] Anglia_Mea_0024.json -> int/UK
# [*] Anglia_Mea_0013.json -> int/UK
# [*] Anglia_Mea_0375.json -> int/UK
# [*] Anglia_Mea_0302.json -> int/UK
# [*] Anglia_Mea_0164.json -> int/UK
# [*] Anglia_Mea_0244.json -> int/UK
# [*] Anglia_Mea_0125.json -> int/UK
# [*] Anglia_Mea_0281.json -> int/UK
# [*] Anglia_Mea_0198.json -> int/UK
# [*] Anglia_Mea_0367.json -> int/UK
# [*] Anglia_Mea_0115.json -> int/UK
# [*] Anglia_Mea_0103.json -> int/UK
# [*] Anglia_Mea_0312.json -> int/UK
# [*] Anglia_Mea_0362.json -> int/UK
# [*] Anglia_Mea_0003.json -> int/UK
# [*] Anglia_Mea_0042.json -> int/UK
# [*] Anglia_Mea_0085.json -> int/UK
# [*] Anglia_Mea_0170.json -> int/UK
# [*] Anglia_Mea_0327.json -> int/UK
# [*] Anglia_Mea_0290.json -> int/UK
# [*] Anglia_Mea_0173.json -> int/UK
# [*] Anglia_Mea_0321.json -> int/UK
# [*] Anglia_Mea_0153.json -> int/UK
# [*] Anglia_Mea_0376.json -> int/UK
# [*] Anglia_Mea_0084.json -> int/UK
# [*] Anglia_Mea_0425.json -> int/UK
# [*] Anglia_Mea_0432.json -> int/UK
# [*] Anglia_Mea_0439.json -> int/UK
# [*] Anglia_Mea_0035.json -> int/UK
# [*] Anglia_Mea_0043.json -> int/UK
# [*] Anglia_Mea_0015.json -> int/UK
# [*] Anglia_Mea_0452.json -> int/UK
# [*] Gazeta_Romaneasca_0292.json -> int/Italia
# [*] Gazeta_Romaneasca_0077.json -> int/Italia
# [*] Gazeta_Romaneasca_0065.json -> int/Italia
# [*] Gazeta_Romaneasca_0457.json -> int/Italia
# [*] Gazeta_Romaneasca_0325.json -> int/Italia
# [*] Gazeta_Romaneasca_0102.json -> int/Italia
# [*] Gazeta_Romaneasca_0075.json -> int/Italia
# [*] Gazeta_Romaneasca_0002.json -> int/Italia
# [*] Gazeta_Romaneasca_0021.json -> int/Italia
# [*] Gazeta_Romaneasca_0376.json -> int/Italia
# [*] Gazeta_Romaneasca_0367.json -> int/Italia
# [*] Gazeta_Romaneasca_0054.json -> int/Italia
# [*] PaginiRomanesti_0743.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0023.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0051.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0960.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0519.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0082.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0483.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0464.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0450.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0649.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0216.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0534.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0217.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0759.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0274.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0287.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0582.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0604.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0221.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0861.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0976.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0103.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0301.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0679.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0586.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0398.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0488.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0592.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0704.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0778.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0579.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0809.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0801.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0472.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0227.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0195.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0096.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0692.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0370.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0703.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0422.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0009.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0533.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0900.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0458.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0648.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0996.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0313.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0397.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0076.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0208.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0793.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0021.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0085.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0298.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0520.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0176.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0646.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0288.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0885.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0429.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0953.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0413.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0041.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0223.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0323.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0265.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0347.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0490.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0170.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0868.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0983.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0856.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0206.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0532.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0676.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0300.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0373.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0528.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0535.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0020.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0424.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0183.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0019.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0294.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0884.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0672.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0637.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0246.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0609.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0618.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0386.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0378.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0948.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0225.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0388.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0749.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0120.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0249.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0518.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0115.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0141.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0366.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0205.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0824.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0273.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0150.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0562.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0540.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0255.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0523.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0973.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0074.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0633.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0463.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0854.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0774.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0987.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0988.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0509.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0769.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0166.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0007.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0420.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0326.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0354.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0517.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0811.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0061.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0903.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0097.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0142.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0331.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0998.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0060.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0218.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0794.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0564.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0189.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0318.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0688.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0330.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0361.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0755.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0599.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0239.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0912.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0106.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0888.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0119.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0459.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0722.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0910.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0086.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0941.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0894.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0878.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0846.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0764.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0619.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0923.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0304.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0033.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0796.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0124.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0746.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0167.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0797.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0454.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0695.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0163.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0038.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0267.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0156.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0966.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0767.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0214.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0147.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0891.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0598.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0083.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0149.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0098.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0043.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0501.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0617.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0073.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0938.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0233.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0979.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0334.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0345.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0766.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0724.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0554.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0367.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0693.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0635.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0896.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0133.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0063.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0090.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0131.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0848.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0383.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0969.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0305.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0068.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0817.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0107.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0003.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0011.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0682.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0282.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0924.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0726.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0810.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0995.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0494.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0198.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0219.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0677.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0940.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0747.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0644.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0731.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0920.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0876.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0253.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0575.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0699.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0309.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0144.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0751.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0498.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0744.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0758.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0444.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0631.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0714.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0190.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0286.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0936.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0828.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0567.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0937.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0605.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0718.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0970.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0660.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0134.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0739.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0187.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0100.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0339.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0689.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0126.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0956.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0493.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0978.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0745.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0538.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0442.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0431.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0013.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0123.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0735.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0843.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0212.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0439.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0942.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0243.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0188.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0548.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0251.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0882.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0667.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0099.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0029.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0741.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0084.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0447.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0736.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0529.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0513.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0853.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0474.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0209.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0890.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0833.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0332.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0665.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0192.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0143.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0236.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0561.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0802.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0473.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0588.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0184.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0823.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0862.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0719.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0655.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0560.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0720.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0220.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0647.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0566.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0328.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0992.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0228.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0348.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0199.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0849.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0959.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0742.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0674.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0062.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0642.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0407.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0436.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0071.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0568.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0654.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0889.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0470.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0852.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0690.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0161.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0522.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0927.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0818.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0048.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0515.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0151.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0448.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0401.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0964.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0785.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0694.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0723.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0353.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0822.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0307.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0186.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0901.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0311.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0621.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0989.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0269.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0197.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0410.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0727.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0346.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0299.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0160.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0816.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0467.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0771.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0997.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0283.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0717.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0138.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0842.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0792.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0506.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0055.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0829.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0712.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0549.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0898.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0496.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0542.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0466.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0476.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0883.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0016.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0034.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0772.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0453.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0728.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0591.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0721.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0675.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0934.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0193.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0748.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0057.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0056.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0303.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0252.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0039.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0930.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0179.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0241.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0957.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0955.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0687.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0102.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0761.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0504.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0112.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0601.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0606.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0002.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0512.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0867.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0757.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0393.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0495.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0994.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0014.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0121.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0658.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0030.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0381.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0881.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0841.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0435.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0485.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0369.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0130.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0931.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0610.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0414.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0752.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0058.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0907.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0434.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0355.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0584.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0893.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0376.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0050.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0109.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0145.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0263.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0834.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0481.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0671.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0510.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0379.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0645.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0821.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0335.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0729.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0232.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0544.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0530.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0886.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0092.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0680.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0491.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0857.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0157.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0782.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0017.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0482.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0697.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0779.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0773.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0111.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0776.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0022.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0278.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0248.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0899.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0716.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0944.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0905.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0603.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0222.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0775.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0070.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0320.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0652.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0915.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0590.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0786.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0597.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0859.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0046.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0390.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0432.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0725.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0789.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0505.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0624.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0536.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0250.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0516.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0780.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0400.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0951.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0181.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0402.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0608.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0152.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0321.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0932.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0611.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0349.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0479.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0791.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0279.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0661.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0531.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0025.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0271.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0581.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0168.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0990.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0276.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0507.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0580.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0831.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0417.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0860.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0657.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0024.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0399.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0042.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0895.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0577.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0337.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0508.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0526.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0069.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0426.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0804.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0285.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0844.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0095.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0734.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0486.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0968.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0364.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0031.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0826.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0653.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0555.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0122.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0832.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0730.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0489.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0329.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0570.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0117.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0678.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0887.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0351.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0800.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0392.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0812.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0200.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0012.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0440.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0229.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0377.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0363.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0104.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0556.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0914.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0004.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0737.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0404.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0240.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0079.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0869.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0456.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0065.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0266.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0164.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0615.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0072.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0806.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0075.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0457.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0845.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0118.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0928.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0433.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0423.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0659.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0550.json -> int/Canada_Quebec
# [*] PaginiRomanesti_0922.json -> int/Canada_Quebec
# ...
# [*] directmm.ro_0015.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0074.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0101.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0030.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0144.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0121.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0076.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0050.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0176.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0029.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0025.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0189.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0001.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0002.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0093.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0083.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0053.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0131.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0032.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0104.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0067.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0070.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0028.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0085.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0034.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0045.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0199.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0006.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0032.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0178.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0183.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0036.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0083.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0125.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0088.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0011.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0011.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0109.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0143.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0100.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0166.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0030.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0079.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0098.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0028.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0069.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0054.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0060.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0039.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0154.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0046.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0058.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0081.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0048.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0084.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0048.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0140.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0177.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0064.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0073.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0125.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0187.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0116.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0087.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0154.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0169.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0021.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0089.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0123.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0184.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0184.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0044.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0027.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0065.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0057.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0004.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0035.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0181.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0010.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0042.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0007.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0114.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0052.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0171.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0007.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0130.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0023.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0127.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0094.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0036.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0110.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0078.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0120.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0197.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0189.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0029.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0024.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0117.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0022.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0031.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0128.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0193.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0190.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0158.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0034.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0113.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0136.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0064.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0107.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0137.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0021.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0023.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0167.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0190.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0017.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0013.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0105.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0118.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0006.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0097.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0013.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0070.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0018.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0081.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0129.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0052.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0110.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0172.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0142.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0186.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0165.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0163.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0139.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0106.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0096.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0145.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0098.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0001.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0142.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0179.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0016.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0107.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0124.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0071.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0106.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0144.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0015.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0194.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0180.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0010.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0008.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0005.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0120.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0019.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0153.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0063.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0050.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0075.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0025.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0014.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0187.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0013.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0157.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0049.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0152.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0102.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0079.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0076.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0137.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0129.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0145.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0104.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0086.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0103.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0017.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0008.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0186.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0045.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0005.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0161.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0150.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0099.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0067.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0171.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0043.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0192.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0066.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0051.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0059.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0148.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0022.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0122.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0055.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0022.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0169.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0198.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0132.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0051.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0112.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0062.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0037.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0176.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0122.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0155.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0173.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0096.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0035.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0002.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0009.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0008.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0160.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0047.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0073.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0038.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0153.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0020.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0147.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0043.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0034.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0038.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0097.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0124.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0099.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0065.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0102.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0113.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0016.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0021.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0041.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0182.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0094.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0130.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0037.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0170.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0011.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0191.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0042.json -> judete/Maramures_cleaned/Maramures
# [*] emaramures.ro_0152.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0027.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0164.json -> judete/Maramures_cleaned/Maramures
# [*] gazetademaramures.ro_0015.json -> judete/Maramures_cleaned/Maramures
# [*] directmm.ro_0077.json -> judete/Maramures_cleaned/Maramures

# %% [markdown]
# Script care genereaza doua fisiere .CSV incapsuland dimensiunile datelor.
#
# Per total
# Per categorie
# Per subcategorie
# Per judet
# Per gazeta

# %%
ROOT = Path("data")
OUT_CSV = "date_agregate.csv"

word_re = re.compile(r"\w+", flags=re.UNICODE)

"""
    Yield path-uri cumulative ale parintilor, inclusiv gazeta, pentru crearea path-ului complet
    Example:
        relative_parent = 'politics/europe'
        gazeta = 'GAZETA'
        -> '(root)', 'politics', 'politics/europe', 'politics/europe/GAZETA'
"""
def ancestors_with_gazeta(relative_parent: Path, gazeta: str):
    
    yield "(root)"
    parts = list(relative_parent.parts)
    acc = []
    for p in parts:
        acc.append(p)
        yield "/".join(acc)
    if gazeta:
        yield "/".join(acc + [gazeta]) if acc else gazeta

"""
    Metricile pe care le folosim pentru fisiere
"""
def content_metrics(s: str):
    if not isinstance(s, str):
        return 0, 0
    s = s.strip()
    return len(s), len(word_re.findall(s))

folder_stats = defaultdict(lambda: {"files": 0, "chars": 0, "words": 0})

processed, skipped = 0, 0

for fp in ROOT.rglob("*.json"):
    try:
        obj = json.loads(fp.read_text(encoding="utf-8"))
    except Exception as e:
        print(f"[skip] {fp}: {e}")
        skipped += 1
        continue

    content = obj.get("content", "")
    chars, words = content_metrics(content)

    # prefix from filename (e.g. "GAZETA" from "GAZETA_123.json")
    fname = fp.name
    gazeta = fname.split("_", 1)[0]

    rel_parent = fp.parent.relative_to(ROOT)

    # Update all ancestor levels + gazeta leaf
    for cat in ancestors_with_gazeta(rel_parent, gazeta):
        folder_stats[cat]["files"]  += 1
        folder_stats[cat]["chars"]  += chars
        folder_stats[cat]["words"]  += words

    processed += 1

# --- write CSV ---
with open(OUT_CSV, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow(["folder_path", "level", "files", "total_content_chars", "total_content_words"])
    def sort_key(item):
        path = item[0]
        depth = 0 if path == "(root)" else path.count("/") + 1
        return (depth, path)
    for path, stats in sorted(folder_stats.items(), key=sort_key):
        level = 0 if path == "(root)" else path.count("/") + 1
        w.writerow([path, level, stats["files"], stats["chars"], stats["words"]])

print(f"Processed: {processed} files; Skipped: {skipped}")
print(f"Saved: {OUT_CSV}")
# Out:
# Processed: 35015 files; Skipped: 0
# Saved: folder_aggregates.csv

# %% [markdown]
# Genereaza un fisier care marcheaza nr. de fisiere fara continut (empty_content.csv)
#
# Genereaza un fisier care marcheaza nr. de gazete ptr care continutul este identic in procent mai mare de 50%

# %%
import hashlib

ROOT = Path("data")
OUT_EMPTY_CSV = "empty_content.csv"
OUT_DUP_CSV   = "gazeta_duplicates.csv"

"Creaza un hash al continutului pentru duplicate detection"
def content_hash(s: str): 
    if not isinstance(s, str):
        return ""
    return hashlib.sha1(s.strip().encode("utf-8")).hexdigest()

empty_files = []
gazeta_hashes = defaultdict(list) 
gazeta_empty_count = Counter()  

processed, skipped = 0, 0

for fp in ROOT.rglob("*.json"):
    try:
        obj = json.loads(fp.read_text(encoding="utf-8"))
    except Exception as e:
        print(f"[skip] {fp}: {e}")
        skipped += 1
        continue

    fname = fp.name
    gazeta = fname.split("_", 1)[0]
    rel_parent = fp.parent.relative_to(ROOT)
    rel_path = fp.relative_to(ROOT).as_posix()

    content = obj.get("content", "")
    chars, words = content_metrics(content)

    # continut gol
    if words == 0:
        empty_files.append([rel_path, gazeta, fname])
        gazeta_empty_count[gazeta] += 1

    # continut pentru duplicate analysis
    h = content_hash(content)
    gazeta_hashes[gazeta].append(h)

    processed += 1

# scriem fisierele care nu au continut
with open(OUT_EMPTY_CSV, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow(["relative_path", "gazeta", "filename"])
    w.writerows(empty_files)

# analizam si cautam gazete care au mai mult de 50% duplicate 
gazeta_dupes = []
for gazeta, hashes in gazeta_hashes.items():
    total = len(hashes)
    unique = len(set(hashes))
    dupes = total - unique
    dup_ratio = dupes / total if total else 0
    if dup_ratio > 0.5: 
        gazeta_dupes.append([gazeta, total, unique, dupes, f"{dup_ratio:.2%}"])

with open(OUT_DUP_CSV, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow(["gazeta", "total_files", "unique_contents", "duplicate_files", "dup_ratio"])
    w.writerows(gazeta_dupes)

print(f"Processed: {processed} files; Skipped: {skipped}")
print(f"Saved: {OUT_EMPTY_CSV}, {OUT_DUP_CSV}")
# Out:
# Processed: 35015 files; Skipped: 0
# Saved: empty_content.csv, gazeta_duplicates.csv

# %%
all_hashes = []
total_files = 0
total_empty = 0
for gazeta, hashes in gazeta_hashes.items():
    total_files += len(hashes)
    all_hashes.extend(hashes)
    total_empty += gazeta_empty_count[gazeta]

unique_all = len(set(all_hashes))
unique_nonempty = unique_all - (1 if total_empty > 0 else 0)
ok_files = unique_nonempty
ok_ratio = (ok_files / total_files) if total_files else 0.0

with open("dataset_quality.csv", "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow([
        "total_files",
        "empty_files",
        "unique_all_incl_empty",
        "unique_nonempty",
        "ok_files",
        "ok_ratio"
    ])
    w.writerow([total_files, total_empty, unique_all, unique_nonempty, ok_files, f"{ok_ratio:.2%}"])
